# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# ---------------- IMAGE 1 ----------------------------
img = plt.imread('/home/santa/Desktop/lab/lab_6/LineHorizontal2.png')
# Convert RGB image to GrayScale image 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Take Fourier at the input image
dft = cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
dft_spectrum = 20*np.log(0.01 + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.figure(figsize=(15,15))

# Show Fourier Spectrum of Input Image
plt.subplot(221)
plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# Show Fourier Spectrum of Input Image
plt.subplot(222)
plt.imshow( dft_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

# ---------------- IMAGE 2 ----------------------------
img = plt.imread('/home/santa/Desktop/lab/lab_6/LineVertical2.png')
# Convert RGB image to GrayScale image 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Take Fourier at the input image
dft = cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
dft_spectrum = 20*np.log(0.01 + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.figure(figsize=(15,15))
# Show Fourier Spectrum of Input Image
plt.subplot(223)
plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# Show Fourier Spectrum of Input Image
plt.subplot(224)
plt.imshow( dft_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# ---------------- IMAGE 3 ----------------------------
img_gray = plt.imread('/home/santa/Desktop/lab/lab_6/LineHorizontal3.png')

# Take Fourier at the input image
dft = cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
dft_spectrum = 20*np.log(0.01 + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.figure(figsize=(15,15))
# Show Fourier Spectrum of Input Image
plt.subplot(221)
plt.imshow(img_gray, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# Show Fourier Spectrum of Input Image
plt.subplot(222)
plt.imshow( dft_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

# ---------------- IMAGE 4 ----------------------------
img_gray = plt.imread('/home/santa/Desktop/lab/lab_6/LineVertical3.png')

# Take Fourier at the input image
dft = cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
dft_spectrum = 20*np.log(0.01 + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.figure(figsize=(15,15))
# Show Fourier Spectrum of Input Image
plt.subplot(223)
plt.imshow(img_gray, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# Show Fourier Spectrum of Input Image
plt.subplot(224)
plt.imshow( dft_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# ---------------- IMAGE 5 ----------------------------
img_gray = plt.imread('/home/santa/Desktop/lab/lab_6/LineImage.jpg')

# Take Fourier at the input image
dft = cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
dft_spectrum = 20*np.log(0.01 + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.figure(figsize=(15,15))
# Show Fourier Spectrum of Input Image
plt.subplot(221)
plt.imshow( img_gray, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# Show Fourier Spectrum of Input Image
plt.subplot(222)
plt.imshow( dft_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.show()
